# %%
# 라이브러리 임포트

import pandas as pd
import tensorflow as tf

# %%
# data 불러오기

Boston = pd.read_csv("/content/boston.csv")
Boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
Boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# 독립변수, 종속변수 분리하기

독립 = Boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]

종속 = Boston[['medv']]

print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 모델 생성

X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(5, activation="swish")(X)
y = tf.keras.layers.Dense(1)(H)

model = tf.keras.models.Model(X, y)
model.compile(loss="mse")

# %%
# 모델 확인
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 70
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 76
# Trainable params: 76
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 학습

# model.fit(독립, 종속, epochs=550, verbose=0)
model.fit(독립, 종속, epochs=15)
# Out:
# Epoch 1/15
# 16/16 [==============================] - 0s 1ms/step - loss: 18.7205
# Epoch 2/15
# 16/16 [==============================] - 0s 1ms/step - loss: 18.3305
# Epoch 3/15
# 16/16 [==============================] - 0s 2ms/step - loss: 18.0134
# Epoch 4/15
# 16/16 [==============================] - 0s 2ms/step - loss: 19.0426
# Epoch 5/15
# 16/16 [==============================] - 0s 2ms/step - loss: 17.5109
# Epoch 6/15
# 16/16 [==============================] - 0s 2ms/step - loss: 19.3578
# Epoch 7/15
# 16/16 [==============================] - 0s 2ms/step - loss: 18.1285
# Epoch 8/15
# 16/16 [==============================] - 0s 2ms/step - loss: 18.0801
# Epoch 9/15
# 16/16 [==============================] - 0s 1ms/step - loss: 18.1310
# Epoch 10/15
# 16/16 [==============================] - 0s 2ms/step - loss: 18.3561
# Epoch 11/15
# 16/16 [==============================] - 0s 2ms/step - loss: 17.7891
# Epoch 12/15
# 16/16 [==============================] - 0s 2ms/step - loss: 18.1013
# Epoch 13/15
# 16/16 [==============================] - 0s 2ms/step - loss: 18.1316
# Epoch 14/15
# 16/16 [==============================] - 0s 1ms/step - loss: 17.9666
# Epoch 15/15
# 16/16 [==============================] - 0s 2ms/step - loss: 17.9257

# %%
# 모델 예측
model.predict(독립)[:5]
# Out:
# array([[32.62727 ],
#        [21.766607],
#        [32.452194],
#        [33.168823],
#        [29.485586]], dtype=float32)

# %%
종속[:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
model.get_weights()
# Out:
# [array([[ 2.37569898e-01,  1.34549722e-01, -1.94190770e-01,
#           3.43154036e-02,  7.33494639e-01],
#         [-4.57987785e-02,  7.13071898e-02, -5.32458544e-01,
#          -6.07206933e-02,  5.85323811e-01],
#         [ 1.57665819e-01,  4.73410219e-01,  2.18850672e-01,
#          -3.18251550e-01,  1.13713726e-01],
#         [-2.03710604e+00,  2.19374561e+00,  1.36076689e-01,
#           1.50219846e+00,  4.52959239e-01],
#         [-6.75000966e-01,  6.69030786e-01, -2.42469937e-01,
#          -9.42336172e-02, -8.02175403e-01],
#         [-2.66967893e+00,  1.99453974e+00, -1.44366622e-01,
#           2.07136869e+00, -5.91717362e-01],
#         [ 2.17967302e-01,  4.20495182e-01, -5.42000234e-01,
#          -2.21245084e-02, -2.58813620e-01],
#         [ 5.10306507e-02, -2.56975144e-01, -2.74774313e-01,
#          -1.56710112e+00,  3.29855442e-01],
#         [-4.16877389e-01, -5.93532026e-01, -2.37391442e-01,
#           6.90454066e-01,  3.98250148e-02],
#         [ 8.22545812e-02,  1.24539666e-01, -3.69153082e-01,
#           1.56355789e-03, -3.07186414e-02],
#         [-8.75149369e-02,  1.88535348e-01,  3.32886696e-01,
#          -1.56282675e+00, -4.21666026e-01],
#         [ 2.27299452e-01,  4.50087279e-01, -5.14903069e-01,
#           1.00944906e-01, -8.43067244e-02],
#         [ 3.50402564e-01, -9.14183259e-02, -9.13990438e-02,
#          -1.97230196e+00,  5.12362830e-02]], dtype=float32),
#  array([-1.3652301 ,  1.3538412 ,  0.        ,  0.26355445, -0.34711632],
#        dtype=float32),
#  array([[-0.64358985],
#         [ 0.3533457 ],
#         [ 0.33474135],
#         [ 0.80592763],
#         [-6.030555  ]], dtype=float32),
#  array([1.3574607], dtype=float32)]
