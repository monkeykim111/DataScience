# %% [markdown]
# #1  데이터 준비하기

# %%
# 라이브러리 사용
import pandas as pd
import tensorflow as tf

# %%
# 데이터 준비
lemonade = pd.read_csv("/content/lemonade.csv")

lemonade.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 독립변수와 종속변수 만들기

독립 = lemonade[["온도"]]
종속 = lemonade[["판매량"]]

print(X.shape, y.shape)
# Out:
# (None, 1) (None, 1)

# %%
# 모델 생성

X = tf.keras.layers.Input(shape=[1])
y = tf.keras.layers.Dense(1)(X)

model = tf.keras.models.Model(X, y)
model.compile(loss='mse')

# %%
# 모델 학습
model.fit(독립, 종속, epochs=10)
# verbose=0 를 하게 되면 화면에 출력을 하지 않는다.
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 2/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 3/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0017
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 5/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 6/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 7/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 9/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 10/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0016

# %%
# 모델 예측

model.predict(독립)
# Out:
# array([[40.048985],
#        [42.025826],
#        [44.002663],
#        [45.9795  ],
#        [47.956337],
#        [49.933174]], dtype=float32)

# %%
종속
# Out:
#    판매량
# 0   40
# 1   42
# 2   44
# 3   46
# 4   48
# 5   50

# %%
model.predict([[15]])

# 독립변수인 온도가 15도일 때, 종속변수인 판매량은 30이 됨
# Out:
# array([[30.164797]], dtype=float32)
