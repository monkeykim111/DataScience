# %%
# 라이브러리 import
import pandas as pd
import tensorflow as tf

# %%
# 데이터 불러오기

(mnist_x, mnist_y), _ = tf.keras.datasets.mnist.load_data()
print(mnist_x.shape, mnist_y.shape)

mnist_x = mnist_x.reshape(60000, 28, 28, 1)
mnist_y = pd.get_dummies(mnist_y)
print(mnist_x.shape, mnist_y.shape)
# Out:
# (60000, 28, 28) (60000,)
# (60000, 28, 28, 1) (60000, 10)

# %%
# 모델 생성

X = tf.keras.layers.Input(shape=[28,28, 1])
H = tf.keras.layers.Conv2D(6, kernel_size=5, padding='same', activation='swish')(X)
H = tf.keras.layers.MaxPool2D()(H)

H = tf.keras.layers.Conv2D(16, kernel_size=5, activation='swish')(H)
H = tf.keras.layers.MaxPool2D()(H)

H = tf.keras.layers.Flatten()(H)
H = tf.keras.layers.Dense(120, activation='swish')(H)
H = tf.keras.layers.Dense(84, activation='swish')(H)
y = tf.keras.layers.Dense(10, activation='softmax')(H)

model = tf.keras.models.Model(X, y)
model.compile(loss='categorical_crossentropy', metrics='accuracy')

# %%
# 모델 학습

model.fit(mnist_x, mnist_y, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 43s 22ms/step - loss: 0.5089 - accuracy: 0.9271
# Epoch 2/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.0898 - accuracy: 0.9759
# Epoch 3/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.0715 - accuracy: 0.9805
# Epoch 4/10
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0616 - accuracy: 0.9846
# Epoch 5/10
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0578 - accuracy: 0.9855
# Epoch 6/10
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0546 - accuracy: 0.9862
# Epoch 7/10
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0526 - accuracy: 0.9872
# Epoch 8/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.0527 - accuracy: 0.9877
# Epoch 9/10
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0529 - accuracy: 0.9884
# Epoch 10/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.0515 - accuracy: 0.9888

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                33684
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                850
# =================================================================
# Total params: 37,106
# Trainable params: 37,106
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h1>Cifar 10

# %%
# 데이터 불러오기

(cifar10_x, cifar10_y), _ = tf.keras.datasets.cifar10.load_data()
print(cifar10_x.shape, cifar10_y.shape)

# cifar10_x = cifar10_x.reshape()
cifar10_y = pd.get_dummies(cifar10_y.reshape(50000))
print(cifar10_x.shape, cifar10_y.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (50000, 32, 32, 3) (50000, 10)

# %%
# 모델 생성

X = tf.keras.layers.Input(shape=[32,32, 3])
H = tf.keras.layers.Conv2D(6, kernel_size=5, activation='swish')(X)
H = tf.keras.layers.MaxPool2D()(H)

H = tf.keras.layers.Conv2D(16, kernel_size=5, activation='swish')(H)
H = tf.keras.layers.MaxPool2D()(H)

H = tf.keras.layers.Flatten()(H)
H = tf.keras.layers.Dense(120, activation='swish')(H)
H = tf.keras.layers.Dense(84, activation='swish')(H)
y = tf.keras.layers.Dense(10, activation='softmax')(H)

model = tf.keras.models.Model(X, y)
model.compile(loss='categorical_crossentropy', metrics='accuracy')

# %%
# 모델 학습

model.fit(cifar10_x, cifar10_y, epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 37s 4ms/step - loss: 1.8993 - accuracy: 0.3520
# Epoch 2/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5356 - accuracy: 0.4536
# Epoch 3/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4508 - accuracy: 0.4894
# Epoch 4/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4065 - accuracy: 0.5080
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3805 - accuracy: 0.5200
# Epoch 6/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3671 - accuracy: 0.5264
# Epoch 7/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3628 - accuracy: 0.5293
# Epoch 8/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3589 - accuracy: 0.5308
# Epoch 9/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3729 - accuracy: 0.5285
# Epoch 10/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3779 - accuracy: 0.5292

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 6)         456
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# _________________________________________________________________
